# %% [raw]
# Hannah Carter
#
# Purifying selection?
# Measures of linkage disequilibrium
#     D
#     R^2
# GWAS
#     Cases and controls you've identify
#     Want to identify loci that correlate with a phenotype in the population
#     There's some ancestral mutation that get inherited in the haplotype
#     Linked to certain haplotype
#     try to find loci that are correlated with the phenotype
#     don't need to know exactly what causes it
#     use snp chips
#         have like a million snps on the chip
#         use fluorescent incorporation to find particular SNP
# Estimating power to detect an association
#     Power = 1 -P(type II error)
#         type II error  = false negative
#     GPC power calculator
#     depends on
#         odds ratio
#         sample size
#         requred signficance
#         phenotype prevalence
#         extent to which tested marker is in LD with the causal marker
# Case-control
#     commonly used tests
#     Pearson's Chi^2
#         Calculate statistic from allelic dontingency table and assess significance
#         need at least 5 counts
#         basically estimate of fisher's exact test
#     Fisher's exact test
#         Assumed to follow a hypergeometric distribution
#         more computationally demanding
#         but can totally use it now
#     Logistic regression
#         Allows for inclusion of covariates
# Multiple genotypes are working together to give the phenotype
# QTL association testing
#     All regression based
#         Linear regression
#         most common model
#         easily include covariates
#         usually fit 1 marker, but can fit several at once
#         See if having a minor allele is asociated with a particular trait value
#     ANOVA
#         Similar to linear regression but focuses on comparing groups of samples
#         Analysis of variation between two or more samples
#         Lots of different types of models
#             fixed effects models
#             ranodm effects models
#             mixed effects models
# Evaluating Assocation Results
#     QQ-plots(quantile-quantile plots)
#         Plot observed statistic vs expected statistic both sorted in increasing order
#         Identify loci that deviate
#     Manhattan plot
#         plot -log10(pvalue) versus increasing genomic coordinate
#         usually use a p value of p<5e-8
#     LocusZoom
#         good tool for digging into what's going on

# %% [raw]
# Other considerations for GWAS
# Disease model
#     Additive
#         Assumes increase in effect from addition of each minor allele
#     Linear regresssion: 2 DF model
# Complicating factors
#     locus heterogeneity
#     pleiotropy
#     epistasis
#     environmental effects
# Environment
#     Phenotypic variance is caused by both genetic variance and environmental variance, but also by the interaction of the two
# Epistasis interaction between loci
# Tools for association testing
#     R, PLINK, GCTA
#     find stuff on bioconductor
# Population substructure
#     Effect sizes resulting from population level
#     Do things to control for it
#     Use PCA to look for population substructure
# Incomplete genealogies
#     based on assumptions of independent samples or samples with known relationships
#     if there some unaccounted for relatedness, it can invalidate your analyses
#     Need to measure this and remove highly related samples
# Mixed effects model
#     Instead of using principal components include a genetic relationship matrix as a random effect in a mixed effects model
#     strategy used by GC

# %% [raw]
# Quantitative Genetics
#     Classical model introduced by Ronald Fisher in 1918
#     You can estimate heritability
# Determining the role of common variation
#     GCTA
#     Mixed effects model incorporating genetic relationship matrix as a random effect
#     Fit phenotype to all SNPs at once
#     Estimate phenotypic variance explained by all SNPs
